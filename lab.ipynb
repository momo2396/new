# %% [markdown]
# ###Lab

# %%
import numpy as np
import scipy as scp
import sympy as sp
import pandas as pd

# %%
#normal eq
import numpy as np
# np.random.seed(0)
x = np.linspace(0, 10, 7)
print(x)
y = 2 * x + 1 + 0.5 * np.random.randn(len(x))
print(y)
# Create the design matrix
X = np.vstack((x, np.ones_like(x))).T
print(X)
# Solve using the normal equation
coefficients = np.linalg.inv(X.T @ X) @ X.T @ y
# Extract the slope and intercept
# slope, intercept = coefficients
print(coefficients)
# Print the results
# print("Optimized slope:", slope)
# print("Optimized intercept:", intercept)
# Out:
# [ 0.          1.66666667  3.33333333  5.          6.66666667  8.33333333
#  10.        ]
# [ 0.84884862  3.80905685  6.9566577  10.1468649  15.30872103 17.41184058
#  20.78096285]
# [[ 0.          1.        ]
#  [ 1.66666667  1.        ]
#  [ 3.33333333  1.        ]
#  [ 5.          1.        ]
#  [ 6.66666667  1.        ]
#  [ 8.33333333  1.        ]
#  [10.          1.        ]]
# [2.04329943 0.53535321]

# %%
import numpy as np
from scipy.optimize import linprog
c = np.array([-1, -2, -1])
A_ub = np.array([[-2, -1, -1],
                [4,2,3],
                [-2,-5,-5]])
b_ub = np.array([-14, -28, -30])
A_eq = np.array([[2.0, 8.0, 1.0, 0.0],
                [4.0, 4.0, 0.0, 1.0]])
# b_eq = np.array([60.0, 60.0])
x0_bounds = (0, None)
x1_bounds = (0, None)
x2_bounds = (0, None)  # +/- np.inf can be used instead of None
bounds = [x0_bounds, x1_bounds, x2_bounds]
# , A_eq=A_eq, b_eq=b_eq,
result = linprog(c, A_ub=A_ub, b_ub=b_ub, bounds=bounds)
print(result.fun)

# c= np.array([1, 2, -1])
# A_ub = np.array([[1,1,1],
#                  [0, -2, 3]])
# b_ub = np.array([0,1])
# A_eq=np.array([[-1, 0, 2]])
# b_eq = np.array([0])
# result = linprog(c, A_ub = A_ub, b_ub=b_ub, A_eq=A_eq, b_eq=b_eq, method='revised simplex')
# print(result)
# Out:
# None

# %%
import numpy as np
from scipy.optimize import linprog
c = np.array([-1, -2, -1])
A_ub = np.array([[-2, -1, -1],
                [4,2,3],
                [-2,-5,-5]])
b_ub = np.array([-14, -28, -30])
A_eq = np.array([[2.0, 8.0, 1.0, 0.0],
                [4.0, 4.0, 0.0, 1.0]])
x0_bounds = (0, None)
x1_bounds = (0, None)
x2_bounds = (0, None)
bounds = [x0_bounds, x1_bounds, x2_bounds]
result = linprog(c, A_ub=A_ub, b_ub=b_ub, bounds=bounds)
print(result)
# Out:
#        message: The problem is infeasible. (HiGHS Status 8: model_status is Infeasible; primal_status is At lower/fixed bound)
#        success: False
#         status: 2
#            fun: None
#              x: None
#            nit: 0
#          lower:  residual: None
#                 marginals: None
#          upper:  residual: None
#                 marginals: None
#          eqlin:  residual: None
#                 marginals: None
#        ineqlin:  residual: None
#                 marginals: None

# %%
import matplotlib.pyplot as plt
import sympy
import math
x, y = sympy.symbols('x y')
y = x**2*sympy.log(1+x)
exp = sympy.series(y, x, n=9)
display(exp)

a= [0,2,3,4]
j=0
b = [0,0,0,0]
for i in a:
    b[j]=i**2*math.log(1+i)
    j+=1
plt.plot(a,b, 'b--', label='x**2*log(1+x)', linewidth='3')
plt.legend()
plt.figure(figsize=(3,5))
plt.show()
a = [4,6,7,8,9,10]
b =[0,0,0,0,0, 0]
j=0
for i in a:
    b[j]=i**2*math.log(1+i)
    j+=1

plt.plot(a,b, 'g', label='x**2*log(1+x)',linewidth='2')
plt.legend()
plt.figure(figsize=(3,5))
plt.show()
# Out:
# x**3 - x**4/2 + x**5/3 - x**6/4 + x**7/5 - x**8/6 + O(x**9)

# %%
import numpy as np
x = np.linspace(2, 10, 4)
y = np.random.randn(len(x))
X =np.vstack((x, np.ones_like(x))).T 
coefficients = np.linalg.inv(X.T @ X) @ X.T @ y
print(coefficients[0])
# Out:
# 0.13981048601640222
